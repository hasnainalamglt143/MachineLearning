# %% [markdown]
# ## loss function for graident desnt is:
#
# ## Mean Squared Error = ![image.png](attachment:3c0de0c0-39b9-4dda-9317-ec76411279a0.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler

# Generate data
X, y = make_regression(n_samples=40, n_features=1, noise=40, random_state=13)

# Normalize X for better gradient descent performance
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X).ravel()

class  GradientDescent:

    def __init__(self,X, y, learning_rate=0.1, epochs=1000):
         self.m = 0
         self.b = 0
         self.n = X.shape[0]
         self.lr=learning_rate
         self.epochs=epochs


    def fit(self,X,y):
        
     for i in range(self.epochs):
            
        y_pred = self.m * X + self.b

        # Corrected gradients
        m_grad = (-2 / self.n) * np.sum((y - y_pred) *X)
        b_grad = (-2 / self.n) * np.sum(y - y_pred)

        # Update parameters
        self.m -= self.n* m_grad
        self.b -= self.n* b_grad
        
        return m, b


    def predict(self,X):
        return self.m * X+ self.b
        

        

# Train
model=GradientDescent(X_scaled, y, learning_rate=0.01,epochs=1000)
model.fit(X,y)


y_pred=model.predict(X)
y_pred

# # Plot
plt.scatter(X_scaled, y, color='blue', label='Data Points')
plt.plot(X[:], ypred, color='red', label='Predicted Line')
plt.title("Gradient Descent Regression")
plt.xlabel("X (scaled)")
plt.ylabel("y")
plt.legend()
plt.show()
